# %%
x = "#"
y = 6
for i in x:
    print(i)
    x = i+i
    print(x)
# Out:
# #
# ##

# %%
x = 1
for i in range(8):
    for j in range(8):
        print('#', end = "")
    print()
# Out:
# ########
# ########
# ########
# ########
# ########
# ########
# ########
# ########

# %%
class Human:
    def __init__(self, fname, lname):
        self.fname = fname
        self.lname = lname
        print(fname, lname)

p1 = Human("harivignesh", "D")
p1.fname
class Animal(Human):
    pass
p2 = Animal("KING", "KONG")
print(p2)
# Out:
# harivignesh D
# KING KONG
# <__main__.Animal object at 0x33c0f78>

# %%
lis = []
#lis[2]
len_lis = len(lis)
if len_lis == 0:
    print("The list is empty")
else:
    print("The list is not empty")
# Out:
# The list is empty

# %%
my_list = [10, 20, 30, 40, 50]
my_list[2] = 200
my_list
my_list.append(600)
my_list
my_list.insert(2, 300)
my_list
my_list.remove(600)
my_list
del my_list[0]
my_list
# Out:
# [20, 300, 200, 40, 50]

# %%
total = sum(my_list)
n = 0
for i in my_list:
    n = n+i
print(n)
# Out:
# 610

# %%
numbers = [10, 20, 30, 40, 50]
num = sum(numbers)
num
aver = num/ len(numbers)
aver
# Out:
# 30.0

# %%
rev = numbers[::-1]
rev
# Out:
# [50, 40, 30, 20, 10]

# %%
my_dict = {'name': 'Alice', 'age': 35, 'city': 'New York'}
my_dict['proffession'] = "Engineer"
my_dict['age'] = 40
my_dict['age']
my_dict
# Out:
# {'name': 'Alice', 'age': 40, 'city': 'New York', 'proffession': 'Engineer'}

# %%
del my_dict['proffession']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 del my_dict['proffession']
#       2 my_dict
#
# KeyError: 'proffession'

# %%
for i,v in my_dict.items():
    print(f"{i} : {v}")
# Out:
# name : Alice
# age : 40
# city : New York
# proffession : Engineer

# %%
my_dict.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 40), ('city', 'New York'), ('proffession', 'Engineer')])

# %%
try:
    print(f)
except NameError:
    print("The file is opening")

else:
    print("Printed the print")
# Out:
# The file is opening
